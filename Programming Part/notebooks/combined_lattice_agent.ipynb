# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))  # "Programming Part" auf sys.path

from env import gymnasium_env as drausp_env
import numpy as np

from env.instance_reader import get_instance_data
import matplotlib.pyplot as plt

data_path = Path("../../instances/lion18s/SA01.txt")

# %%
DRAUSP_data = get_instance_data(data_path)

K = DRAUSP_data.num_slots
T_d = 10  # Anzahl Anfragen pro Episode; entspricht Instanz "SA1" (K=4, |N|=50, C=10, T_d=10) aus Tabelle 2 des Papers, Z*=5.08
C_k = DRAUSP_data.capacity_vector
instance = DRAUSP_data.instance
request_length = DRAUSP_data.request_length
pool_size = DRAUSP_data.pool_size
print(K)
print(T_d)
print(pool_size)
print(C_k)
print(instance)
# Out:
# 4
# 10
# 50
# [10, 10, 10, 10]
# [[41, 1, 1, 0, 0], [39, 1, 1, 0, 0], [20, 1, 3, 0, 0], [61, 2, 1, 0, 0], [18, 2, 1, 0, 0], [23, 1, 4, 0, 0], [25, 1, 1, 0, 0], [13, 1, 1, 0, 0], [77, 1, 1, 0, 0], [8, 1, 2, 0, 0], [25, 1, 3, 0, 0], [74, 1, 1, 0, 0], [39, 1, 3, 0, 0], [54, 3, 2, 0, 0], [70, 1, 3, 0, 0], [71, 1, 1, 0, 0], [55, 1, 1, 0, 0], [9, 1, 1, 0, 0], [96, 1, 1, 0, 0], [63, 3, 2, 0, 0], [50, 3, 2, 0, 0], [20, 1, 1, 0, 0], [43, 1, 2, 0, 0], [74, 1, 2, 0, 0], [62, 1, 1, 0, 0], [60, 1, 1, 0, 0], [22, 1, 1, 0, 0], [81, 1, 2, 0, 0], [92, 1, 1, 0, 0], [80, 1, 1, 0, 0], [38, 2, 1, 0, 0], [84, 1, 1, 0, 0], [39, 1, 2, 0, 0], [88, 2, 1, 0, 0], [69, 1, 3, 0, 0], [21, 2, 1, 0, 0], [15, 1, 1, 0, 0], [47, 3, 1, 0, 0], [67, 1, 1, 0, 0], [18, 1, 1, 0, 0], [87, 1, 1, 0, 0], [58, 1, 2, 0, 0], [34, 2, 1, 0, 0], [8, 1, 1, 0, 0], [97, 1, 1, 0, 0], [73, 1, 1, 0, 0], [54, 1, 1, 0, 0], [69, 2, 1, 0, 0], [79, 1, 2, 0, 0], [9, 1, 2, 0, 0]]

# %%
env = drausp_env.DrauspEnv(K=K, T_d=T_d, C_k=C_k, instance=instance, render_mode="human", fixed_request_length=request_length)

# %%
from training.dqn_agent import DQNAgent
from models.lattice_dqn import LatticeDQNNetwork
from models.lattice_dqn_withaction import LatticeDQNNetworkWithAction
agent = DQNAgent(env, QnetworkClass=LatticeDQNNetworkWithAction, reject_bias = 0.75, gamma = 0.98, epsilon_decay_steps=5000)

# %%
reward_history, monotonicity_violations, depth_history = agent.train(num_episodes=2000)
# Out:
#   Systematic monotonicity (Episode 1): C_k: 100.0%, t: 47.2%, r: 45.0%, q: 37.5%, mixed: 100.0%
# Episode   50/2000  Reward:    76.00  Avg(50):   119.32  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.914
#   Systematic monotonicity (Episode 51): C_k: 100.0%, t: 55.6%, r: 75.0%, q: 67.5%, mixed: 100.0%
# Episode  100/2000  Reward:   194.00  Avg(50):   159.32  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.837
#   Systematic monotonicity (Episode 101): C_k: 100.0%, t: 100.0%, r: 87.5%, q: 37.5%, mixed: 100.0%
# Episode  150/2000  Reward:   276.00  Avg(50):   216.62  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.767
#   Systematic monotonicity (Episode 151): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 0.0%, mixed: 100.0%
# Episode  200/2000  Reward:   400.00  Avg(50):   235.82  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.703
#   Systematic monotonicity (Episode 201): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 30.0%, mixed: 100.0%
# Episode  250/2000  Reward:   142.00  Avg(50):   232.20  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.646
#   Systematic monotonicity (Episode 251): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 7.5%, mixed: 100.0%
# Episode  300/2000  Reward:   107.00  Avg(50):   248.92  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.594
#   Systematic monotonicity (Episode 301): C_k: 100.0%, t: 100.0%, r: 100.0%, q: 0.0%, mixed: 100.0%
# Episode  350/2000  Reward:   244.00  Avg(50):   273.14  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.547
#   Systematic monotonicity (Episode 351): C_k: 100.0%, t: 88.9%, r: 97.5%, q: 35.0%, mixed: 100.0%
# Episode  400/2000  Reward:   219.00  Avg(50):   303.76  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.504
#   Systematic monotonicity (Episode 401): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 0.0%, mixed: 100.0%
# Episode  450/2000  Reward:   247.00  Avg(50):   332.08  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.466
#   Systematic monotonicity (Episode 451): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 0.0%, mixed: 100.0%
# Episode  500/2000  Reward:   362.00  Avg(50):   351.24  Tiefe:    7  Avg-Tiefe(50):    9.8  ε: 0.432
#   Systematic monotonicity (Episode 501): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 0.0%, mixed: 100.0%
# Episode  550/2000  Reward:   602.00  Avg(50):   326.78  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.400
#   Systematic monotonicity (Episode 551): C_k: 100.0%, t: 100.0%, r: 100.0%, q: 25.0%, mixed: 100.0%
# Episode  600/2000  Reward:   380.00  Avg(50):   346.50  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.372
#   Systematic monotonicity (Episode 601): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 55.0%, mixed: 100.0%
# Episode  650/2000  Reward:   341.00  Avg(50):   390.68  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.346
#   Systematic monotonicity (Episode 651): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 52.5%, mixed: 100.0%
# Episode  700/2000  Reward:   283.00  Avg(50):   373.48  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.323
#   Systematic monotonicity (Episode 701): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 65.0%, mixed: 100.0%
# Episode  750/2000  Reward:   307.00  Avg(50):   369.12  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.301
#   Systematic monotonicity (Episode 751): C_k: 100.0%, t: 100.0%, r: 87.5%, q: 67.5%, mixed: 100.0%
# Episode  800/2000  Reward:   425.00  Avg(50):   390.14  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.282
#   Systematic monotonicity (Episode 801): C_k: 100.0%, t: 100.0%, r: 82.5%, q: 77.5%, mixed: 100.0%
# Episode  850/2000  Reward:   494.00  Avg(50):   402.46  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.265
#   Systematic monotonicity (Episode 851): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 72.5%, mixed: 100.0%
# Episode  900/2000  Reward:   281.00  Avg(50):   388.18  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.249
#   Systematic monotonicity (Episode 901): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 97.5%, mixed: 100.0%
# Episode  950/2000  Reward:   496.00  Avg(50):   387.02  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.235
#   Systematic monotonicity (Episode 951): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 97.5%, mixed: 100.0%
# Episode 1000/2000  Reward:   611.00  Avg(50):   409.52  Tiefe:   10  Avg-Tiefe(50):    9.8  ε: 0.223
#   Systematic monotonicity (Episode 1001): C_k: 100.0%, t: 100.0%, r: 85.0%, q: 100.0%, mixed: 100.0%
# Episode 1050/2000  Reward:   421.00  Avg(50):   386.12  Tiefe:   10  Avg-Tiefe(50):    9.8  ε: 0.211
#   Systematic monotonicity (Episode 1051): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 97.5%, mixed: 100.0%
# Episode 1100/2000  Reward:   697.00  Avg(50):   436.54  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.201
#   Systematic monotonicity (Episode 1101): C_k: 100.0%, t: 100.0%, r: 80.0%, q: 97.5%, mixed: 100.0%
# Episode 1150/2000  Reward:   575.00  Avg(50):   440.76  Tiefe:   10  Avg-Tiefe(50):    9.7  ε: 0.191
#   Systematic monotonicity (Episode 1151): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 97.5%, mixed: 100.0%
# Episode 1200/2000  Reward:   515.00  Avg(50):   423.70  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.183
#   Systematic monotonicity (Episode 1201): C_k: 100.0%, t: 100.0%, r: 95.0%, q: 95.0%, mixed: 100.0%
# Episode 1250/2000  Reward:   260.00  Avg(50):   411.44  Tiefe:    8  Avg-Tiefe(50):    9.8  ε: 0.175
#   Systematic monotonicity (Episode 1251): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 87.5%, mixed: 100.0%
# Episode 1300/2000  Reward:   438.00  Avg(50):   436.76  Tiefe:    8  Avg-Tiefe(50):    9.9  ε: 0.168
#   Systematic monotonicity (Episode 1301): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 95.0%, mixed: 100.0%
# Episode 1350/2000  Reward:   458.00  Avg(50):   429.08  Tiefe:   10  Avg-Tiefe(50):    9.8  ε: 0.162
#   Systematic monotonicity (Episode 1351): C_k: 100.0%, t: 100.0%, r: 95.0%, q: 92.5%, mixed: 100.0%
# Episode 1400/2000  Reward:   622.00  Avg(50):   448.22  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.156
#   Systematic monotonicity (Episode 1401): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 92.5%, mixed: 100.0%
# Episode 1450/2000  Reward:   381.00  Avg(50):   417.20  Tiefe:   10  Avg-Tiefe(50):    9.9  ε: 0.151
#   Systematic monotonicity (Episode 1451): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 87.5%, mixed: 100.0%
# Episode 1500/2000  Reward:   517.00  Avg(50):   418.20  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.146
#   Systematic monotonicity (Episode 1501): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 85.0%, mixed: 100.0%
# Episode 1550/2000  Reward:   251.00  Avg(50):   435.92  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.141
#   Systematic monotonicity (Episode 1551): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 82.5%, mixed: 100.0%
# Episode 1600/2000  Reward:   548.00  Avg(50):   435.86  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.137
#   Systematic monotonicity (Episode 1601): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 92.5%, mixed: 100.0%
# Episode 1650/2000  Reward:   551.00  Avg(50):   436.12  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.134
#   Systematic monotonicity (Episode 1651): C_k: 100.0%, t: 100.0%, r: 95.0%, q: 87.5%, mixed: 100.0%
# Episode 1700/2000  Reward:   321.00  Avg(50):   461.38  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.131
#   Systematic monotonicity (Episode 1701): C_k: 100.0%, t: 100.0%, r: 90.0%, q: 87.5%, mixed: 100.0%
# Episode 1750/2000  Reward:   549.00  Avg(50):   464.00  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.128
#   Systematic monotonicity (Episode 1751): C_k: 100.0%, t: 100.0%, r: 100.0%, q: 95.0%, mixed: 100.0%
# Episode 1800/2000  Reward:   474.00  Avg(50):   434.98  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.125
#   Systematic monotonicity (Episode 1801): C_k: 100.0%, t: 100.0%, r: 87.5%, q: 95.0%, mixed: 100.0%
# Episode 1850/2000  Reward:   566.00  Avg(50):   450.66  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.123
#   Systematic monotonicity (Episode 1851): C_k: 100.0%, t: 100.0%, r: 92.5%, q: 72.5%, mixed: 100.0%
# Episode 1900/2000  Reward:   476.00  Avg(50):   465.26  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.121
#   Systematic monotonicity (Episode 1901): C_k: 100.0%, t: 100.0%, r: 80.0%, q: 80.0%, mixed: 100.0%
# Episode 1950/2000  Reward:   377.00  Avg(50):   452.22  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.119
#   Systematic monotonicity (Episode 1951): C_k: 100.0%, t: 100.0%, r: 97.5%, q: 75.0%, mixed: 100.0%
# Episode 2000/2000  Reward:   569.00  Avg(50):   437.80  Tiefe:   10  Avg-Tiefe(50):   10.0  ε: 0.117

# %%
from training.plotting import plot_training_progress, plot_depth_epsilon

plot_training_progress(reward_history, monotonicity_violations)

# %%
plot_depth_epsilon(depth_history)

# %%
import torch
net = agent.policy_net
net.eval()
obs, _ = env.reset()
print("Initial observation:", obs)
obs = [3,6,7,4,3,41,1,1,0,0]
modified_obs = obs.copy()
modified_obs[1:5] = [10,10,10,10]  
obs = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
modified_obs_t = torch.tensor(modified_obs, dtype=torch.float32).unsqueeze(0)
with torch.no_grad():
    q_values = net(obs)
    print("Q-values for initial state:", q_values)  
    q_values_modified = net(modified_obs_t)
    print("Q-values for modified state:", q_values_modified)
# Out:
# Initial observation: [ 1. 10. 10. 10. 10. 60.  1.  1.  0.  0.]
# Q-values for initial state: tensor([[171.5599, 195.3568, 206.2426, 225.7128]])
# Q-values for modified state: tensor([[343.9268, 378.2181, 363.7898, 376.4934]])

# %%
obs, _ = env.reset()
obs = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
done = False
cumulated_reward = 0.0

while not done:
                # 1. Aktion wählen
                action = net(obs)
                action = torch.argmax(action, dim=1).item()  # Greedy Aktion
                # 2. Umgebungsschritt
                next_obs, reward, terminated, truncated, _ = env.step(action)
                done = terminated or truncated

                obs = next_obs
                obs = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
                cumulated_reward += reward
print(cumulated_reward)
# Out:
# 237.0

# %%
import torch

net = agent.policy_net
K = net.K

# Einen echten State holen
obs, _ = env.reset()
obs = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)

with torch.no_grad():
    q_dqn   = net.dqn(obs)
    q_total = net(obs)
    bonus   = q_total - q_dqn

print(f"Q_dqn:   {q_dqn.numpy().flatten()}")
print(f"Bonus:   {bonus.numpy().flatten()[0]:.3f}")
print(f"Q_total: {q_total.numpy().flatten()}")
# Out:
# Q_dqn:   [404.08777 473.7404  458.083   473.37405]
# Bonus:   3.746
# Q_total: [407.8336  477.4862  461.82883 477.11987]

# %% [markdown]
# Teste ob der Bonus einen wirklichen Einfluss hat

# %%
import torch

net = agent.policy_net
K = net.K

# Einen echten State holen
obs, _ = env.reset()
obs = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)

with torch.no_grad():
    q_dqn   = net.dqn(obs)
    q_total = net(obs)
    bonus   = q_total - q_dqn

print(f"Q_dqn:   {q_dqn.numpy().flatten()}")
print(f"Bonus:   {bonus.numpy().flatten()[0]:.3f}")
print(f"Q_total: {q_total.numpy().flatten()}")
# Out:
# Q_dqn:   [400.75082 411.2775  395.82004 414.8649 ]
# Bonus:   3.746
# Q_total: [404.49664 415.02332 399.56586 418.61072]

# %% [markdown]
# Bonus erfüllt die Monotonieeigenschaft

# %%
for c_val in [0.0, 5.0, 10.0]:
    c_raw = torch.tensor([[c_val] * K], dtype=torch.float32)
    with torch.no_grad():
        c_cal = torch.cat(
            [cal(c_raw[:, k:k+1].double()).float()
             for k, cal in enumerate(net.c_calibrators)],
            dim=1,
        )
        bonus = net.c_lattice(c_cal.double()).float().item()
    print(f"C_k = {c_val:.0f}  →  Bonus = {bonus:.3f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 9
#       3 with torch.no_grad():
#       4     c_cal = torch.cat(
#       5         [cal(c_raw[:, k:k+1].double()).float()
#       6          for k, cal in enumerate(net.c_calibrators)],
#       7         dim=1,
#       8     )
# ----> 9     bonus = net.c_lattice(c_cal.double()).float().item()
#      10 print(f"C_k = {c_val:.0f}  →  Bonus = {bonus:.3f}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pytorch_lattice\layers\lattice.py:130, in Lattice.forward(self, x)
#     128 x = [xi.double() for xi in x] if isinstance(x, list) else x.double()
#     129 if self.interpolation == Interpolation.HYPERCUBE:
# --> 130     return self._compute_hypercube_interpolation(x)
#     131 if self.interpolation == Interpolation.SIMPLEX:
#     132     return self._compute_simplex_interpolation(x)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pytorch_lattice\layers\lattice.py:394, in Lattice._compute_hypercube_interpolation(self, inputs)
#     390 interpolation_weights = self._compute_hypercube_interpolation_weights(
#     391     inputs=inputs, clip_inputs=self.clip_inputs
#     392 )
#     393 if self.units == 1:
# --> 394     return torch.matmul(interpolation_weights, self.kernel)
#     396 return torch.sum(interpolation_weights * self.kernel.t(), dim=-1)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x16 and 32x1)
